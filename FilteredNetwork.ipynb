# %%
import numpy as np
import pandas as pd

file_enron = './datasets/enron-v1.csv'
enron_data = pd.read_csv(file_enron)
enron_data

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns  # also improves the look of plots
sns.set()  # set Seaborn defaults
plt.rcParams['figure.figsize'] = [10, 5]  # default hor./vert. size of plots, in inches
plt.rcParams['lines.markeredgewidth'] = 1  # to fix issue with seaborn box plots; needed after import seaborn

import plotly.graph_objects as go
import networkx as nx
from pyvis.network import Network
from pyvis import network as net
import dash
import dash_cytoscape as cyto
from dash.dependencies import Input, Output
import dash_core_components as dcc
import dash_html_components as html
from random import random
import json

app = dash.Dash(__name__)
server = app.server

# %%
SusEmails = enron_data

# %%
search = input("Filter:")
jobtitleifst = ((search == 'Trader') | (search == 'Unknown') | (search == 'Vice President') | (search == 'Employee') | (search == 'Managing Director') | (search == 'Manager') | (search == 'President') | (search == 'Director') | (search == 'CEO') | (search == 'In House Lawyer'))
joblist = ['Trader', 'Unkown', 'Vice President', 'Employee', 'Managing Director', 'President', 'Manager', 'Director', 'CEO', 'In House Lawyer']

if ";" in search:
    if (search.partition(";")[0] in joblist and search.partition(";")[2] in joblist):
        CertainMails = ((SusEmails['fromJobtitle'] == search.partition(";")[0]) & (SusEmails['toJobtitle'] == search.partition(";")[2]))
        SusEmails = SusEmails[CertainMails]
    elif ("@" in search.partition(";")[0] and "@" in search.partition(";")[2]):
        CertainMails = ((SusEmails['fromEmail'] == search.partition(";")[0]) & (SusEmails['toEmail'] == search.partition(";")[2]))
        SusEmails = SusEmails[CertainMails]
    elif ("-" in search.partition(";")[0] and "-" in search.partition(";")[2]):
        CertainMails = ((SusEmails["date"] >= search.partition(";")[0]) & (SusEmails["date"] <= search.partition(";")[2]))
        SusEmails = SusEmails[CertainMails]

elif ";" not in search:
    if "@" in search:
        CertainMails = ((SusEmails['fromEmail'] == search) | (SusEmails['toEmail'] == search))
        SusEmails = SusEmails[CertainMails]
    elif "-" in search:
        CertainMails = (SusEmails['date'] == search)
        SusEmails = SusEmails[CertainMails]
    elif jobtitleifst:
        CertainMails = ((SusEmails['fromJobtitle'] == search) | (SusEmails['toJobtitle'] == search))
        SusEmails = SusEmails[CertainMails]
    elif (search == "clear"):
        SusEmails = enron_data
# Out:
# Filter:Manager;Employee

# %%
enron_string = SusEmails.astype(str)
enron_string
# Out:
#              date fromId                fromEmail fromJobtitle toId  \
# 40     2001-10-01     99   mike.grigsby@enron.com      Manager  113
# 96     2002-01-30     24      m..forney@enron.com      Manager   72
# 178    2001-02-08     25    john.arnold@enron.com      Manager   79
# 310    2001-11-18     99   mike.grigsby@enron.com      Manager  113
# 319    2001-11-26     99   mike.grigsby@enron.com      Manager   41
# ...           ...    ...                      ...          ...  ...
# 30376  2001-08-19    148     j.kaminski@enron.com      Manager  123
# 30484  2002-01-17     24      m..forney@enron.com      Manager   72
# 30512  2001-03-25     25    john.arnold@enron.com      Manager   79
# 30721  2001-10-09     29  john.griffith@enron.com      Manager   53
# 30796  2001-12-04     24      m..forney@enron.com      Manager   72
#
#                             toEmail toJobtitle messageType  \
# 40                 l..gay@enron.com   Employee          TO
# 96     doug.gilbert-smith@enron.com   Employee          TO
# 178      errol.mclaughlin@enron.com   Employee          TO
# 310                l..gay@enron.com   Employee          TO
# 319         jay.reitmeyer@enron.com   Employee          TO
# ...                             ...        ...         ...
# 30376          sally.beck@enron.com   Employee          TO
# 30484  doug.gilbert-smith@enron.com   Employee          CC
# 30512    errol.mclaughlin@enron.com   Employee          TO
# 30721          brad.mckay@enron.com   Employee          TO
# 30796  doug.gilbert-smith@enron.com   Employee          TO
#
#                   sentiment
# 40                      0.0
# 96                      0.0
# 178                     0.0
# 310      0.0136986301369863
# 319    -0.05263157894736848
# ...                     ...
# 30376                   0.0
# 30484                   0.0
# 30512                   0.0
# 30721  -0.05263157894736848
# 30796    0.0136986301369863
#
# [377 rows x 9 columns]

# %%
emailfromName = enron_string['fromEmail']
emailtoName = enron_string['toEmail']
emailName = np.concatenate((emailfromName,emailtoName))
fromId = enron_string['fromId']
toId = enron_string['toId']
emailId = np.concatenate((fromId, toId))

IdList = []
for i in emailId:
    if i not in IdList:
        IdList.append(i)
NameList = []
for i in emailName:
    if i not in NameList:
        NameList.append(i)

node_data = zip(IdList,NameList)
target_data = zip(fromId,toId)

def removeDuplicates(target_data):
    return list(set([i for i in target_data]))
clean_target_data = removeDuplicates(target_data)

nodes = [{'data':{'id':item[0], 'label':item[1]}, 'position': {'x': (random()*1000), 'y':(random()*1000)}} for item in node_data]
edges = [{'data':{'source':item[0], 'target':item[1]}} for item in clean_target_data]

cyto_data = nodes + edges
cyto_data
# Out:
# [{'data': {'id': '99', 'label': 'mike.grigsby@enron.com'},
#   'position': {'x': 667.9859907282362, 'y': 734.1497440991897}},
#  {'data': {'id': '24', 'label': 'm..forney@enron.com'},
#   'position': {'x': 173.763899813581, 'y': 817.1265052529695}},
#  {'data': {'id': '25', 'label': 'john.arnold@enron.com'},
#   'position': {'x': 852.0715531444242, 'y': 957.6748979891242}},
#  {'data': {'id': '110', 'label': 'phillip.k.ellen@enron.com'},
#   'position': {'x': 891.5737018866274, 'y': 296.5065149082734}},
#  {'data': {'id': '58', 'label': 'chris.dorland@enron.com'},
#   'position': {'x': 968.4229812397236, 'y': 138.63677685699005}},
#  {'data': {'id': '148', 'label': 'j.kaminski@enron.com'},
#   'position': {'x': 351.02830694545094, 'y': 399.6537115606694}},
#  {'data': {'id': '91', 'label': 'martin.cuilla@enron.com'},
#   'position': {'x': 840.6213174964435, 'y': 900.2183179354911}},
#  {'data': {'id': '29', 'label': 'john.griffith@enron.com'},
#   'position': {'x': 767.436845192259, 'y': 860.899290561849}},
#  {'data': {'id': '142', 'label': 'teb.lokey@enron.com'},
#   'position': {'x': 740.2799637238004, 'y': 181.41824174769715}},
#  {'data': {'id': '117', 'label': 'rick.buy@enron.com'},
#   'position': {'x': 37.627763559423876, 'y': 680.4736508416206}},
#  {'data': {'id': '43', 'label': 'jeff.king@enron.com'},
#   'position': {'x': 219.51469429835447, 'y': 572.9544688793588}},
#  {'data': {'id': '101', 'label': 'mike.carson@enron.com'},
#   'position': {'x': 198.06336575151317, 'y': 466.4478618650202}},
#  {'data': {'id': '65', 'label': 'daren.j.farmer@enron.com'},
#   'position': {'x': 729.1545551950212, 'y': 944.1787557213455}},
#  {'data': {'id': '113', 'label': 'l..gay@enron.com'},
#   'position': {'x': 54.69902902065738, 'y': 787.5585207289645}},
#  {'data': {'id': '72', 'label': 'doug.gilbert-smith@enron.com'},
#   'position': {'x': 61.893504674020214, 'y': 434.2834714664191}},
#  {'data': {'id': '79', 'label': 'errol.mclaughlin@enron.com'},
#   'position': {'x': 601.0142726548983, 'y': 973.7214728146562}},
#  {'data': {'id': '41', 'label': 'jay.reitmeyer@enron.com'},
#   'position': {'x': 912.4388058314865, 'y': 31.196570619475782}},
#  {'data': {'id': '96', 'label': 'matthew.lenhart@enron.com'},
#   'position': {'x': 798.7027165553282, 'y': 969.5121912182565}},
#  {'data': {'id': '22', 'label': 'kam.keiser@enron.com'},
#   'position': {'x': 59.36645709689658, 'y': 719.0390066765626}},
#  {'data': {'id': '123', 'label': 'sally.beck@enron.com'},
#   'position': {'x': 835.1308429076366, 'y': 732.3543008892866}},
#  {'data': {'id': '53', 'label': 'brad.mckay@enron.com'},
#   'position': {'x': 678.2814580446981, 'y': 72.15169707389268}},
#  {'data': {'id': '109', 'label': 'peter.keavey@enron.com'},
#   'position': {'x': 639.2076248073773, 'y': 516.6297152965997}},
#  {'data': {'id': '42', 'label': 'jeff.dasovich@enron.com'},
#   'position': {'x': 500.33116502853636, 'y': 536.2223180721347}},
#  {'data': {'id': '3', 'label': 'lindy.donoho@enron.com'},
#   'position': {'x': 85.81744682227688, 'y': 204.8821425185362}},
#  {'data': {'id': '8', 'label': 'kate.symes@enron.com'},
#   'position': {'x': 897.436558812536, 'y': 519.6825108231582}},
#  {'data': {'id': '97', 'label': 'michelle.cash@enron.com'},
#   'position': {'x': 508.608177011701, 'y': 828.3588689227347}},
#  {'data': {'id': '147', 'label': 'tracy.geaccone@enron.com'},
#   'position': {'x': 590.0884275433649, 'y': 686.5907091266527}},
#  {'data': {'id': '67', 'label': 'c..giron@enron.com'},
#   'position': {'x': 28.838083615531417, 'y': 729.95455151284}},
#  {'data': {'id': '103', 'label': 'monika.causholli@enron.com'},
#   'position': {'x': 391.734828186745, 'y': 654.6323433203918}},
#  {'data': {'id': '75', 'label': 'elizabeth.sager@enron.com'},
#   'position': {'x': 185.68534887613518, 'y': 52.130964720083604}},
#  {'data': {'id': '106', 'label': 'paul.lucci@enron.com'},
#   'position': {'x': 444.66510830467456, 'y': 534.380477016794}},
#  {'data': {'id': '50', 'label': 'benjamin.rogers@enron.com'},
#   'position': {'x': 347.2113154893973, 'y': 877.9671037269172}},
#  {'data': {'id': '111', 'label': 'phillip.platter@enron.com'},
#   'position': {'x': 575.9877676039398, 'y': 427.41370969261084}},
#  {'data': {'id': '18', 'label': 'larry.f.campbell@enron.com'},
#   'position': {'x': 956.0808723387455, 'y': 819.5426500455835}},
#  {'data': {'id': '31', 'label': 'juan.hernandez@enron.com'},
#   'position': {'x': 94.99934193602466, 'y': 255.0135215305256}},
#  {'data': {'id': '62', 'label': 'dan.hyvl@enron.com'},
#   'position': {'x': 574.6561905814247, 'y': 274.52196202825553}},
#  {'data': {'id': '54', 'label': 'cara.semperger@enron.com'},
#   'position': {'x': 112.93631124131132, 'y': 376.3002558504492}},
#  {'data': {'id': '98', 'label': 'michelle.lokay@enron.com'},
#   'position': {'x': 214.2984312323333, 'y': 885.7228414630724}},
#  {'data': {'id': '2', 'label': 'mark.e.taylor@enron.com'},
#   'position': {'x': 435.6518187062758, 'y': 179.03582527203943}},
#  {'data': {'source': '25', 'target': '79'}},
#  {'data': {'source': '58', 'target': '41'}},
#  {'data': {'source': '142', 'target': '147'}},
#  {'data': {'source': '29', 'target': '50'}},
#  {'data': {'source': '29', 'target': '79'}},
#  {'data': {'source': '99', 'target': '113'}},
#  {'data': {'source': '148', 'target': '97'}},
#  {'data': {'source': '24', 'target': '103'}},
#  {'data': {'source': '91', 'target': '53'}},
#  {'data': {'source': '110', 'target': '41'}},
#  {'data': {'source': '29', 'target': '109'}},
#  {'data': {'source': '91', 'target': '106'}},
#  {'data': {'source': '65', 'target': '62'}},
#  {'data': {'source': '99', 'target': '41'}},
#  {'data': {'source': '91', 'target': '96'}},
#  {'data': {'source': '24', 'target': '31'}},
#  {'data': {'source': '24', 'target': '8'}},
#  {'data': {'source': '91', 'target': '109'}},
#  {'data': {'source': '25', 'target': '53'}},
#  {'data': {'source': '110', 'target': '2'}},
#  {'data': {'source': '58', 'target': '96'}},
#  {'data': {'source': '148', 'target': '50'}},
#  {'data': {'source': '110', 'target': '113'}},
#  {'data': {'source': '24', 'target': '72'}},
#  {'data': {'source': '110', 'target': '42'}},
#  {'data': {'source': '24', 'target': '111'}},
#  {'data': {'source': '99', 'target': '67'}},
#  {'data': {'source': '25', 'target': '109'}},
#  {'data': {'source': '142', 'target': '18'}},
#  {'data': {'source': '99', 'target': '109'}},
#  {'data': {'source': '24', 'target': '54'}},
#  {'data': {'source': '148', 'target': '147'}},
#  {'data': {'source': '110', 'target': '123'}},
#  {'data': {'source': '99', 'target': '96'}},
#  {'data': {'source': '142', 'target': '3'}},
#  {'data': {'source': '101', 'target': '72'}},
#  {'data': {'source': '24', 'target': '75'}},
#  {'data': {'source': '110', 'target': '22'}},
#  {'data': {'source': '148', 'target': '123'}},
#  {'data': {'source': '99', 'target': '22'}},
#  {'data': {'source': '110', 'target': '96'}},
#  {'data': {'source': '65', 'target': '113'}},
#  {'data': {'source': '29', 'target': '53'}},
#  {'data': {'source': '142', 'target': '98'}},
#  {'data': {'source': '43', 'target': '72'}},
#  {'data': {'source': '110', 'target': '106'}},
#  {'data': {'source': '117', 'target': '123'}}]

# %%
graph_roots = ["#" + Id for Id in fromId]
clean_graph_roots = []
for i in graph_roots:
    if i not in clean_graph_roots:
        clean_graph_roots.append(i)
comma_separated_roots = ", ".join(clean_graph_roots)
comma_separated_roots
# Out:
# '#99, #24, #25, #110, #58, #148, #91, #29, #142, #117, #43, #101, #65'

# %%
app = dash.Dash(__name__)
server = app.server


default_stylesheet = [
    {
        "selector": 'node',
        'style': {
            "opacity": 0.65,'shape': 'rectangle'
        }
    },
    {
        "selector": 'edge',
        'style': {
            "curve-style": "bezier",
            "opacity": 0.65
        }
    },
]

styles = {
    'json-output': {
        'overflow-y': 'scroll',
        'height': 'calc(50% - 25px)',
        'border': 'thin lightgrey solid'
    },
    'tab': {
        'height': 'calc(98vh - 105px)'
    }
}

app.layout = html.Div([
    html.Div(className='eight columns', children=[
        cyto.Cytoscape(
            id='cytoscape',
            layout={'name': 'breadthfirst','roots':comma_separated_roots},
            elements=cyto_data,
            style={
                'height': '95vh',
                'width': '100%'
            }
        ),
                html.P(id='cytoscape-mouseoverNodeData-output'),
    ])
])


@app.callback(Output('tap-node-json-output', 'children'),
              [Input('cytoscape', 'tapNode')])
def display_tap_node(data):
    return json.dumps(data, indent=2)


@app.callback(Output('tap-edge-json-output', 'children'),
              [Input('cytoscape', 'tapEdge')])
def display_tap_edge(data):
    return json.dumps(data, indent=2)


@app.callback(Output('cytoscape', 'stylesheet'),
              [Input('cytoscape', 'tapNode')])
def generate_stylesheet(node):
    follower_color = '#0074D9'
    following_color = '#FF4136'
    node_shape = 'rectangle'
    if not node:
        return default_stylesheet

    stylesheet = [{
        "selector": 'node',
        'style': {
            'opacity': 0.3,
            'shape': node_shape
        }
    }, {
        'selector': 'edge',
        'style': {
            'opacity': 0.2,
            "curve-style": "bezier",
        }
    }, {
        "selector": 'node[id = "{}"]'.format(node['data']['id']),
        "style": {
            'background-color': '#B10DC9',
            "border-color": "purple",
            "border-width": 2,
            "border-opacity": 1,
            "opacity": 1,

            "label": "data(label)",
            "color": "#B10DC9",
            "text-opacity": 1,
            "font-size": 12,
            'z-index': 9999
        }
    }]

    for edge in node['edgesData']:
        if edge['source'] == node['data']['id']:
            stylesheet.append({
                "selector": 'node[id = "{}"]'.format(edge['target']),
                "style": {
                    'background-color': following_color,
                    'opacity': 0.9
                }
            })
            stylesheet.append({
                "selector": 'edge[id= "{}"]'.format(edge['id']),
                "style": {
                    "mid-target-arrow-color": following_color,
                    "mid-target-arrow-shape": "vee",
                    "line-color": following_color,
                    'opacity': 0.9,
                    'z-index': 5000
                }
            })

        if edge['target'] == node['data']['id']:
            stylesheet.append({
                "selector": 'node[id = "{}"]'.format(edge['source']),
                "style": {
                    'background-color': follower_color,
                    'opacity': 0.9,
                    'z-index': 9999
                }
            })
            
            stylesheet.append({
                "selector": 'edge[id= "{}"]'.format(edge['id']),
                "style": {
                    "mid-target-arrow-color": follower_color,
                    "mid-target-arrow-shape": "vee",
                    "line-color": follower_color,
                    'opacity': 1,
                    'z-index': 5000
                }
            })

    return stylesheet


if __name__ == '__main__':
    app.run_server(debug=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [14/May/2021 13:14:08] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2021 13:14:08] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2021 13:14:08] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2021 13:14:09] "POST /_dash-update-component HTTP/1.1" 200 -
# 127.0.0.1 - - [14/May/2021 13:14:10] "POST /_dash-update-component HTTP/1.1" 200 -
